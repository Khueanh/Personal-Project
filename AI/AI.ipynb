# %% [markdown]
# #**Import The Dataset**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
pd.set_option("display.max_columns",30)
pd.set_option("display.max_colwidth",None)
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"/content/global_ai_tools_students_use.csv")

# %% [markdown]
# # **Explore Data**

# %%
df.describe()
# Out:
#               age  usefulness_chatgpt  usefulness_gemini  \
# count  500.000000           115.00000         123.000000
# mean    15.970000             8.13913           7.983740
# std      1.425891             1.31714           1.408311
# min     14.000000             6.00000           6.000000
# 25%     15.000000             7.00000           7.000000
# 50%     16.000000             8.00000           8.000000
# 75%     17.000000             9.00000           9.000000
# max     18.000000            10.00000          10.000000
#
#        usefulness_grammarly  usefulness_quillbot  usefulness_notion_ai  \
# count            122.000000           122.000000            114.000000
# mean               8.008197             8.073770              8.201754
# std                1.507534             1.379712              1.396455
# min                6.000000             6.000000              6.000000
# 25%                6.250000             7.000000              7.000000
# 50%                8.000000             8.000000              8.000000
# 75%                9.000000             9.000000              9.000000
# max               10.000000            10.000000             10.000000
#
#        usefulness_phind  usefulness_edu_chat  usefulness_other
# count        127.000000           105.000000        100.000000
# mean           7.858268             8.114286          7.960000
# std            1.429421             1.482684          1.427861
# min            6.000000             6.000000          6.000000
# 25%            7.000000             7.000000          7.000000
# 50%            8.000000             8.000000          8.000000
# 75%            9.000000             9.000000          9.000000
# max           10.000000            10.000000         10.000000

# %%
df.head()
# Out:
#   student_id  age  gender country grade  uses_ai_for_study  uses_chatgpt  \
# 0      S0001   17  Female   India  12th               True         False
# 1      S0002   18  Female  Canada  10th               True         False
# 2      S0003   16    Male      UK  12th              False         False
# 3      S0004   18  Female      UK  10th              False         False
# 4      S0005   18    Male     USA  11th               True         False
#
#    uses_gemini  uses_grammarly  uses_quillbot  uses_notion_ai  uses_phind  \
# 0        False           False          False            True       False
# 1         True           False           True           False       False
# 2        False           False          False           False       False
# 3        False           False          False           False       False
# 4        False            True          False           False       False
#
#    uses_edu_chat  uses_other  usefulness_chatgpt  usefulness_gemini  \
# 0          False        True                 NaN                NaN
# 1          False       False                 NaN                9.0
# 2          False       False                 NaN                NaN
# 3          False       False                 NaN                NaN
# 4           True       False                 NaN                NaN
#
#    usefulness_grammarly  usefulness_quillbot  usefulness_notion_ai  \
# 0                   NaN                  NaN                   6.0
# 1                   NaN                 10.0                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   NaN                  NaN                   NaN
# 4                  10.0                  NaN                   NaN
#
#    usefulness_phind  usefulness_edu_chat  usefulness_other
# 0               NaN                  NaN               6.0
# 1               NaN                  NaN               NaN
# 2               NaN                  NaN               NaN
# 3               NaN                  NaN               NaN
# 4               NaN                  8.0               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            500 non-null    object
#  1   age                   500 non-null    int64
#  2   gender                500 non-null    object
#  3   country               500 non-null    object
#  4   grade                 500 non-null    object
#  5   uses_ai_for_study     500 non-null    bool
#  6   uses_chatgpt          500 non-null    bool
#  7   uses_gemini           500 non-null    bool
#  8   uses_grammarly        500 non-null    bool
#  9   uses_quillbot         500 non-null    bool
#  10  uses_notion_ai        500 non-null    bool
#  11  uses_phind            500 non-null    bool
#  12  uses_edu_chat         500 non-null    bool
#  13  uses_other            500 non-null    bool
#  14  usefulness_chatgpt    115 non-null    float64
#  15  usefulness_gemini     123 non-null    float64
#  16  usefulness_grammarly  122 non-null    float64
#  17  usefulness_quillbot   122 non-null    float64
#  18  usefulness_notion_ai  114 non-null    float64
#  19  usefulness_phind      127 non-null    float64
#  20  usefulness_edu_chat   105 non-null    float64
#  21  usefulness_other      100 non-null    float64
# dtypes: bool(9), float64(8), int64(1), object(4)
# memory usage: 55.3+ KB

# %%
df.shape
# Out:
# (500, 22)

# %%
df.dtypes
# Out:
# student_id               object
# age                       int64
# gender                   object
# country                  object
# grade                    object
# uses_ai_for_study          bool
# uses_chatgpt               bool
# uses_gemini                bool
# uses_grammarly             bool
# uses_quillbot              bool
# uses_notion_ai             bool
# uses_phind                 bool
# uses_edu_chat              bool
# uses_other                 bool
# usefulness_chatgpt      float64
# usefulness_gemini       float64
# usefulness_grammarly    float64
# usefulness_quillbot     float64
# usefulness_notion_ai    float64
# usefulness_phind        float64
# usefulness_edu_chat     float64
# usefulness_other        float64
# dtype: object

# %% [markdown]
# # **Data Handling & Cleaning¶**

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'country', 'grade', 'uses_ai_for_study',
#        'uses_chatgpt', 'uses_gemini', 'uses_grammarly', 'uses_quillbot',
#        'uses_notion_ai', 'uses_phind', 'uses_edu_chat', 'uses_other',
#        'usefulness_chatgpt', 'usefulness_gemini', 'usefulness_grammarly',
#        'usefulness_quillbot', 'usefulness_notion_ai', 'usefulness_phind',
#        'usefulness_edu_chat', 'usefulness_other'],
#       dtype='object')

# %%
cols = [
    "usefulness_chatgpt", "usefulness_gemini", "usefulness_grammarly",
    "usefulness_quillbot", "usefulness_notion_ai", "usefulness_phind",
    "usefulness_edu_chat", "usefulness_other"
]

for col in cols:
    df[col] = df[col].fillna(df[col].mode()[0])  # Filling nan values

# %%
df.isna().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["student_id"],inplace=True) # Removing Columns For Better Readability

# %% [markdown]
# # **EDA & Visualization**

# %% [markdown]
# ## **Histogram Distribution**

# %%
for col in df:
    plt.figure(figsize=(12,6))
    sns.histplot(data=df,x=col,kde=True,hue="gender",palette="bright",edgecolor="black")
    plt.title(f"The Distribution Of {col}")
    plt.grid()
    plt.show()

# %% [markdown]
# ## **Categorical Classification By Gender**

# %%
classifi_tf=df.groupby(['age', 'gender', 'country', 'grade', 'uses_ai_for_study',
       'uses_chatgpt', 'uses_gemini', 'uses_grammarly', 'uses_quillbot',
       'uses_notion_ai', 'uses_phind', 'uses_edu_chat', 'uses_other',]).size().reset_index(name="count")
classifi_tf
# Out:
#      age      gender    country grade  uses_ai_for_study  uses_chatgpt  \
# 0     14      Female  Australia  11th               True         False
# 1     14      Female  Australia  11th               True         False
# 2     14      Female  Australia  12th               True         False
# 3     14      Female  Australia  12th               True         False
# 4     14      Female  Australia   9th              False         False
# ..   ...         ...        ...   ...                ...           ...
# 486   18  Non-binary      India  12th              False         False
# 487   18  Non-binary      India  12th               True          True
# 488   18  Non-binary      Japan  12th              False         False
# 489   18  Non-binary      Japan   9th              False         False
# 490   18  Non-binary         UK  11th               True         False
#
#      uses_gemini  uses_grammarly  uses_quillbot  uses_notion_ai  uses_phind  \
# 0          False           False           True            True       False
# 1          False            True           True            True        True
# 2          False           False          False           False       False
# 3           True           False          False            True       False
# 4          False           False          False           False       False
# ..           ...             ...            ...             ...         ...
# 486        False           False          False           False       False
# 487        False            True          False           False       False
# 488        False           False          False           False       False
# 489        False           False          False           False       False
# 490        False           False           True            True       False
#
#      uses_edu_chat  uses_other  count
# 0            False       False      1
# 1             True        True      1
# 2            False       False      1
# 3             True       False      1
# 4            False       False      1
# ..             ...         ...    ...
# 486          False       False      1
# 487          False       False      1
# 488          False       False      1
# 489          False       False      1
# 490          False        True      1
#
# [491 rows x 14 columns]

# %%
g = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_ai_for_study",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="plasma",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("AI Usage For Study by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'AI Usage For Study by Gender Across Countries')

# %%
h = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_chatgpt",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="Set1",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Chat GPT Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Chat GPT Usage by Gender Across Countries')

# %%
i = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_gemini",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="Set2",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Gemini Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Gemini Usage by Gender Across Countries')

# %%
j = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_grammarly",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="Paired",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Grammarly Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Grammarly Usage by Gender Across Countries')

# %%
k = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_quillbot",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="PiYG",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Quillbot Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Quillbot Usage by Gender Across Countries')

# %%
l = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_notion_ai",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="viridis",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Notion Ai Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Notion Ai Usage by Gender Across Countries')

# %%
m = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_phind",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="magma",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Phind Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Phind Usage by Gender Across Countries')

# %%
n = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_edu_chat",
    col="country",
    kind="count",
    col_wrap=5,  # Adjust this depending on number of countries
    palette="cividis",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle("Edu Chat Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, 'Edu Chat Usage by Gender Across Countries')

# %%
o = sns.catplot(
    data=classifi_tf,
    x="gender",
    hue="uses_other",
    col="country",
    kind="count",
    col_wrap=5,
    palette="inferno",
    height=4
)
sns.set_style("whitegrid")
plt.grid()
plt.subplots_adjust(top=0.9)
plt.suptitle(" Other AI Usage by Gender Across Countries",size=15)
# Out:
# Text(0.5, 0.98, ' Other AI Usage by Gender Across Countries')

# %%
bins = [13, 15, 17, 19]  # edges: 14-15, 16-17, 18
labels = ['14-15', '16-17', '18+']

# Add age group column
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

print(df)
# Out:
#      age  gender      country grade  uses_ai_for_study  uses_chatgpt  \
# 0     17  Female        India  12th               True         False
# 1     18  Female       Canada  10th               True         False
# 2     16    Male           UK  12th              False         False
# 3     18  Female           UK  10th              False         False
# 4     18    Male          USA  11th               True         False
# ..   ...     ...          ...   ...                ...           ...
# 495   14  Female      Nigeria   9th               True         False
# 496   16    Male           UK  10th               True         False
# 497   14    Male  South Korea   9th               True         False
# 498   14    Male  South Korea  11th               True         False
# 499   14    Male           UK  10th               True         False
#
#      uses_gemini  uses_grammarly  uses_quillbot  uses_notion_ai  uses_phind  \
# 0          False           False          False            True       False
# 1           True           False           True           False       False
# 2          False           False          False           False       False
# 3          False           False          False           False       False
# 4          False            True          False           False       False
# ..           ...             ...            ...             ...         ...
# 495        False           False           True           False       False
# 496        False           False          False           False       False
# 497         True           False          False           False        True
# 498         True            True           True           False       False
# 499        False           False          False           False       False
#
#      uses_edu_chat  uses_other  usefulness_chatgpt  usefulness_gemini  \
# 0            False        True                 9.0                8.0
# 1            False       False                 9.0                9.0
# 2            False       False                 9.0                8.0
# 3            False       False                 9.0                8.0
# 4             True       False                 9.0                8.0
# ..             ...         ...                 ...                ...
# 495          False        True                 9.0                8.0
# 496          False        True                 9.0                8.0
# 497          False       False                 9.0               10.0
# 498          False        True                 9.0                6.0
# 499          False       False                 9.0                8.0
#
#      usefulness_grammarly  usefulness_quillbot  usefulness_notion_ai  \
# 0                     6.0                  8.0                   6.0
# 1                     6.0                 10.0                   8.0
# 2                     6.0                  8.0                   8.0
# 3                     6.0                  8.0                   8.0
# 4                    10.0                  8.0                   8.0
# ..                    ...                  ...                   ...
# 495                   6.0                  8.0                   8.0
# 496                   6.0                  8.0                   8.0
# 497                   6.0                  8.0                   8.0
# 498                   7.0                  9.0                   8.0
# 499                   6.0                  8.0                   8.0
#
#      usefulness_phind  usefulness_edu_chat  usefulness_other age_group
# 0                 6.0                  9.0               6.0       18+
# 1                 6.0                  9.0               9.0       18+
# 2                 6.0                  9.0               9.0     16-17
# 3                 6.0                  9.0               9.0       18+
# 4                 6.0                  8.0               9.0       18+
# ..                ...                  ...               ...       ...
# 495               6.0                  9.0               9.0     14-15
# 496               6.0                  9.0               6.0     16-17
# 497               9.0                  9.0               9.0     14-15
# 498               6.0                  9.0               9.0     14-15
# 499               6.0                  9.0               9.0     14-15
#
# [500 rows x 22 columns]

# %% [markdown]
# ## **Which Gender, Age Group And What Grade Uses AI For Study**

# %%
classifi_ai=df.groupby(["gender","grade","age_group","uses_ai_for_study"]).size().reset_index(name="count")
classifi_ai=classifi_ai.sort_values("count",ascending=False)
classifi_ai
plt.figure(figsize=(12,6))
sns.barplot(data=classifi_ai,x="age_group",y="count",hue="uses_ai_for_study",edgecolor="black",ci=None,palette="plasma")
plt.tight_layout()
plt.title("Age Group That Uses Ai For Study",size=13)
plt.xlabel("Age Group",size=10)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=classifi_ai,x="grade",y="count",hue="gender",edgecolor="black",ci=None,palette="PiYG")
plt.tight_layout()
plt.title("Genders And Grades Classification That Uses Ai For Study",size=13)
plt.show()

# %% [markdown]
# # **Correlation Heatmap**

# %%
cor=df.select_dtypes(include="number").corr()
plt.figure(figsize=(12,8))
sns.heatmap(data=cor,annot=True,fmt=".2f")
plt.show()

# %% [markdown]
# # **Usage and Usefulness**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %%
students_use = pd.read_csv('/content/global_ai_tools_students_use.csv')
usefulness = pd.read_csv('/content/ai_tool_usefulness_scores.csv')
usage_breakdown = pd.read_csv('/content/ai_tool_usage_breakdown.csv')
usage_breakdown.rename(columns={usage_breakdown.columns[0]: 'AI_Tool'}, inplace=True)

# %%
usage_cols = [col for col in students_use.columns if col.startswith('uses_')]
usefulness_cols = [col for col in students_use.columns if col.startswith('usefulness_')]

# Average usage
usage_percent = students_use[usage_cols].mean().sort_values(ascending=False) * 100
usage_df = usage_percent.reset_index()
usage_df.columns = ['AI_Tool', 'Usage_Percentage']
usage_df['AI_Tool'] = usage_df['AI_Tool'].str.replace('uses_', '').str.replace('_', ' ').str.title()

# Plot usage
plt.figure(figsize=(10,6))
sns.barplot(data=usage_df, x='Usage_Percentage', y='AI_Tool', palette='viridis')
plt.title('AI Tool Usage Among Students')
plt.xlabel('Percentage of Students Using')
plt.ylabel('AI Tool')
plt.tight_layout()
plt.show()

# %%
# Extract average usefulness scores
usefulness_df = students_use[usefulness_cols].mean().reset_index()
usefulness_df.columns = ['AI_Tool', 'Average_Usefulness']
usefulness_df['AI_Tool'] = usefulness_df['AI_Tool'].str.replace('usefulness_', '').str.replace('_', ' ').str.title()

# Merge with usage
merged = pd.merge(usage_df, usefulness_df, on='AI_Tool')

# Scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(data=merged, x='Usage_Percentage', y='Average_Usefulness', hue='AI_Tool', s=100)
plt.title('Usage vs. Perceived Usefulness of AI Tools')
plt.xlabel('Usage Percentage')
plt.ylabel('Average Usefulness (1-5)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
